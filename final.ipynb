# %%
a=input("Enter \n0 for ENCODING\n1 for DECODING\n2 For COMPARING Orignal Image and Encrypted Image[on basis of Pixel Intensity Values] \n")
if int(a)==0:
    # %run ./ENCODE.ipynb
elif int(a)==1:
    # %run ./DECODE.ipynb
elif int(a)==2:
    # %run ./COMPARISION.ipynb
else:
    print("WRONG INPUT")
# Out:
# Enter
# 0 for ENCODING
# 1 for DECODING
# 2 For COMPARING Orignal Image and Encrypted Image[on basis of Pixel Intensity Values]
# 0
# [*] Maximum bytes to encode: 3825
# [*] Encoding data...
# [*] Encoding SUCCESSFULL.
# [*] TIER-1 ENCRYPTED.
# [*] THIS IMAGE MESSAGE HAS TO BE SENT TO BATTALION_23
# [*] TIER-2 ENCRYPTED.
